# %%
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt  

# %matplotlib  inline
print("Modules Imported")
# Out:
# Modules Imported

# %%
#Browse in Kaggle found https://www.kaggle.com/vascodegama/uk-covid19-data?select=England_Regions_COVID_Dataset.csv
df = pd.read_csv('England_Regions_COVID_Dataset.csv')

# %%
df.shape
# Out:
# (2500, 10)

# %%
df.head(15)
# Out:
#           date    areaName  newCasesByPublishDate  cumCasesByPublishDate  \
# 0   2020-01-05  South East                      0                    NaN
# 1   2020-01-06  South East                      0                    NaN
# 2   2020-01-07  South East                      0                    NaN
# 3   2020-01-08  South East                      0                    NaN
# 4   2020-01-09  South East                      0                    NaN
# 5   2020-01-10  South East                      0                    NaN
# 6   2020-01-11  South East                      0                    NaN
# 7   2020-01-12  South East                      0                    NaN
# 8   2020-01-13  South East                      0                    NaN
# 9   2020-01-14  South East                      0                    NaN
# 10  2020-01-15  South East                      0                    NaN
# 11  2020-01-16  South East                      0                    NaN
# 12  2020-01-17  South East                      0                    NaN
# 13  2020-01-18  South East                      0                    NaN
# 14  2020-01-19  South East                      0                    NaN
#
#     newDeaths28DaysByPublishDate  cumDeaths28DaysByPublishDate  \
# 0                              0                           NaN
# 1                              0                           NaN
# 2                              0                           NaN
# 3                              0                           NaN
# 4                              0                           NaN
# 5                              0                           NaN
# 6                              0                           NaN
# 7                              0                           NaN
# 8                              0                           NaN
# 9                              0                           NaN
# 10                             0                           NaN
# 11                             0                           NaN
# 12                             0                           NaN
# 13                             0                           NaN
# 14                             0                           NaN
#
#     cumDeaths28DaysByPublishDateRate  newDeaths28DaysByDeathDate  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# 5                                NaN                         NaN
# 6                                NaN                         NaN
# 7                                NaN                         NaN
# 8                                NaN                         NaN
# 9                                NaN                         NaN
# 10                               NaN                         NaN
# 11                               NaN                         NaN
# 12                               NaN                         NaN
# 13                               NaN                         NaN
# 14                               NaN                         NaN
#
#     cumDeaths28DaysByDeathDate  cumDeaths28DaysByDeathDateRate
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# 5                          NaN                             NaN
# 6                          NaN                             NaN
# 7                          NaN                             NaN
# 8                          NaN                             NaN
# 9                          NaN                             NaN
# 10                         NaN                             NaN
# 11                         NaN                             NaN
# 12                         NaN                             NaN
# 13                         NaN                             NaN
# 14                         NaN                             NaN

# %%
df.insert(1, 'weekday', (pd.to_datetime(df.date).dt.day_name()))

# %%
df.head()
# Out:
#          date    weekday    areaName  newCasesByPublishDate  \
# 0  2020-01-05     Sunday  South East                      0
# 1  2020-01-06     Monday  South East                      0
# 2  2020-01-07    Tuesday  South East                      0
# 3  2020-01-08  Wednesday  South East                      0
# 4  2020-01-09   Thursday  South East                      0
#
#    cumCasesByPublishDate  newDeaths28DaysByPublishDate  \
# 0                    NaN                             0
# 1                    NaN                             0
# 2                    NaN                             0
# 3                    NaN                             0
# 4                    NaN                             0
#
#    cumDeaths28DaysByPublishDate  cumDeaths28DaysByPublishDateRate  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#    newDeaths28DaysByDeathDate  cumDeaths28DaysByDeathDate  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    cumDeaths28DaysByDeathDateRate
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# In step 6 i.e.  df.insert(1, 'weekday', (pd.to_datetime(df.date).dt.day_name()))
# A new column is being inserted at position 1 called weekday next to date at position 0.  In the column the values of the date column are being converted using the python datetime module and then to the name of the day using pandas
